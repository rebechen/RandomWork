# %%
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 7.2.0

# %%
from PIL import Image
import numpy as np 
from PIL import Image
from numpy import asarray

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = image.imread('kk.png')
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (242, 300, 4)

# %%
# load the image
image = Image.open('kk.png')
# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)
# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))
# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# <class 'numpy.ndarray'>
# (242, 300, 4)
# <class 'PIL.Image.Image'>
# RGBA
# (300, 242)

# %%
im = np.array(Image.open('kk.png').convert('L')) #you can pass multiple arguments in single line
print(type(im))

gr_im= Image.fromarray(im).save('gr_kk.png')
# Out:
# <class 'numpy.ndarray'>

# %%
load_img_rz = np.array(Image.open('kk.png').resize((200,200)))
Image.fromarray(load_img_rz).save('r_kk.png')
print("After resizing:",load_img_rz.shape)
im = np.array(Image.open('kk.png'))
print("Before trimming:",im.shape)
im_trim = im[128:384, 128:384]
print("After trimming:",im_trim.shape)
Image.fromarray(im_trim).save('trim_kk.png')
# Out:
# After resizing: (200, 200, 4)
# Before trimming: (242, 300, 4)
# After trimming: (114, 172, 4)

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = image.imread('kk.png')#'kk.png'kolala.jpeg
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (242, 300, 4)

# %%
y = data
z = np.copy(data)

# %%
seed =132
colorlist = [255]
for i in range(0,len(z)):
    for j in range(0,len(z[0])):
        for k in range(0,len(z[0][0])):
            if z[i][j][k] !=255:
                z[i][j][k] = randint(0,256)

# %%
from matplotlib import image
from matplotlib import pyplot
image = image.imread('kk.png')
print(image.dtype)
print(image.shape)
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (242, 300, 4)

# %%
im = Image.fromarray(z.astype('uint8'))
im#.show()
# Out:
# <PIL.Image.Image image mode=RGBA size=300x242 at 0x7F95F0766F10>

# %%
from PIL import Image 
image_file = Image.open("kk.png") # open colour image
image_file = image_file.convert('L') # convert image to black and white
image_file.save('kk2.png')
image_file
# Out:
# <PIL.Image.Image image mode=L size=300x242 at 0x7F95EEC6EA00>

# %%
from matplotlib import image
from matplotlib import pyplot
image = image.imread('kk2.png')
print(image.dtype)
print(image.shape)
pyplot.imshow(image)
pyplot.show()
# Out:
# float32
# (242, 300)
