# %%
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 7.2.0

# %%
from PIL import Image
import numpy as np 
from numpy import asarray
import os
from random import seed
from random import randint
from matplotlib import image
from matplotlib import pyplot

# %%
#creat a folder to save your generated images
#os.makedirs("result")

# %%
###check saved path####
#import sys
#print(os.getcwd())
#print(sys.argv[0])
#print(os.path.dirname(os.path.realpath('__file__'))) ##this is the folder you want to run this program

# %%
# load and display an image with Matplotlib
# load image as pixel array
image1 = image.imread('image1.png')
# summarize shape of the pixel array
print(image1.dtype)
print(image1.shape)
# display the array of pixels as an image
pyplot.imshow(image1)
pyplot.show()
# Out:
# float32
# (210, 210, 4)

# %%
image2 = image.imread('image2.png')
print(image2.dtype)
print(image2.shape)
pyplot.imshow(image2)
pyplot.show()
# Out:
# float32
# (210, 210, 4)

# %%
image3 = image.imread('image3.png')
print(image3.dtype)
print(image3.shape)
pyplot.imshow(image3)
pyplot.show()
# Out:
# float32
# (210, 210, 4)

# %%
list_png=os.listdir()
for png in list_png[:]: 
    if not(png.endswith(".png")):
        list_png.remove(png)
print(list_png)
# Out:
# ['image1.png', 'image2.png', 'image3.png']

# %%
    colorlist = []
    im = Image.open("results/48 .png") 
    # Quantize down to n colour palettised image using *"Fast Octree"* method:
    q = im.quantize(colors=4,method=2)
    for i in range(0,4*3,3):
        color = q.getpalette()[i:i+3]
        colorlist.append(color)
colorlist

# %%
#fetch top three color 
def FetchTopColor(picname,n):
    colorlist = []
    im = Image.open(list_png[0]) 
    # Quantize down to n colour palettised image using *"Fast Octree"* method:
    q = im.quantize(colors=n,method=2)
    for i in range(0,n*3,3):
        color = q.getpalette()[i:i+3]
        colorlist.append(color)
    return colorlist

# %%
#dirname = os.path.dirname(__file__)
def changeColor(image_file,colorlist,x,TopColor):
    im = Image.open(image_file)
    data = np.array(im)
    c = randint(0,50)
    ###########changecolor###########
    for i in range(0,TopColor-1):
        seed(c+x+i) 
        r1, g1, b1 = colorlist[i][0], colorlist[i][1], colorlist[i][2] # Original value
        r2,g2,b2 = randint(0,256),randint(0,256),randint(0,256)
        red, green, blue = data[:,:,0], data[:,:,1], data[:,:,2]
        mask = (red == r1) & (green == g1) & (blue == b1)
        data[:,:,:3][mask] = [r2, g2, b2]
    image_file = image_file.replace(".png","")
    im = Image.fromarray(data)
    im.save(os.path.dirname(os.path.realpath('__file__')) + '/results/' + (str(x)) + '.png')
    saved=image.imread(os.path.dirname(os.path.realpath('__file__')) + '/results/' + (str(x)) + '.png')
    pyplot.imshow(saved)
    pyplot.show()

    return f"Done {image_file}"

# %%
a=19841984 #randome seed change to whatever number you like
TopColor= 5 # fetch top N color, in this case, it is 5
freq_list = []
pic_num = 50 
for i in range(0,pic_num ): # generate 
    seed(a+i)
    print('This is',str(i)+'.png')
    b=randint(0,len(list_png)-1)
    selectedimage = image.imread(list_png[b])
    colorlist =FetchTopColor(list_png[b],TopColor)
    new_image = changeColor(list_png[b],colorlist, i,TopColor)  
    freq_list.append(b)
    if i >= pic_num -1:
        print('Done!')
        pass
    else:
        pyplot.imshow(selectedimage)
# Out:
# This is 0.png
# This is 1.png
# This is 2.png
# This is 3.png
# This is 4.png
# This is 5.png
# This is 6.png
# This is 7.png
# This is 8.png
# This is 9.png
# This is 10.png
# This is 11.png
# This is 12.png
# This is 13.png
# This is 14.png
# This is 15.png
# This is 16.png
# This is 17.png
# This is 18.png
# This is 19.png
# This is 20.png
# This is 21.png
# This is 22.png
# This is 23.png
# This is 24.png
# This is 25.png
# This is 26.png
# This is 27.png
# This is 28.png
# This is 29.png
# This is 30.png
# This is 31.png
# This is 32.png
# This is 33.png
# This is 34.png
# This is 35.png
# This is 36.png
# This is 37.png
# This is 38.png
# This is 39.png
# This is 40.png
# This is 41.png
# This is 42.png
# This is 43.png
# This is 44.png
# This is 45.png
# This is 46.png
# This is 47.png
# This is 48.png
# This is 49.png
# Done!

# %%
#check image frequency if you need
def CountFrequency(my_list):
    # Creating an empty dictionary 
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    for key, value in freq.items():
        print ("% d : % d"%(key, value))
CountFrequency(freq_list)
# Out:
#  1 :  19
#  0 :  16
#  2 :  15

# %%
#results is the folder you save generated images
im = Image.open(os.path.dirname(os.path.realpath('__file__'))+"/results/3.png")
im.rotate(0).show()

# %%
im = Image.open(os.path.dirname(os.path.realpath('__file__'))+"/results/3.png")
im.rotate(45).show()
